# %% [markdown]
# # Assignment No 3a
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement a Decision Tree Classifier.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %% [markdown]
# ### Decision Tree Classifier
#
# Now in this assignment we will be implementing the Decision Classifier for both Continuous and Categorical attributes.
#
# You will be testing your implementations with three different split criterias, namely:
#  - Information Gain
#  - Gini Index
#  - CART

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class Node:
    def __init__(self,purity,klasslabel='',score=0,split=[],fidx=-1):
        self.lchild=None       
        self.rchild=None
        self.klasslabel=klasslabel        
        self.split=split
        self.score=score
        self.fidx=fidx
        self.purity=purity
        
    def set_childs(self,lchild,rchild):
        # YOUR CODE HERE
        self.lchild = lchild
        self.rchild = rchild

        
    def isleaf(self):
        # YOUR CODE HERE
        return (self.lchild == None and self.rchild == None)

#     def isless_than_eq(self, X):
# #         YOUR CODE HERE
#         return (X <= self.value)

        
    def get_str(self):        
        if self.isleaf():
            return 'C(class={},Purity={})'.format(self.klasslabel,self.purity)
        else:
            return 'I(Fidx={},Score={},Split={})'.format(self.fidx,self.score,self.split)

# %%
# A placeholder class 
# TODO: You have to implement the following class, remember from the lectures that you will 
# need to build a model for each different class you are trying to identify...

# %%
import pdb
## Your code goes here...
# You might need to define auxliary classes for composition.. ?
def calculateSplitScore(N,n):

    total1 = float(sum(N))
    dy = 0
    for i in N:
        temp = i/total1
        if temp == 0:
            temp = 1
        dy = dy + -(i/float(total1))*np.log2(temp)
    N2 = n - N
    total2 = float(sum(N2))
    dn = 0
    for j in N2:
        temp = j/total2
        if temp == 0:
            temp = 1
        dn = dn + -(j/float(total2))*np.log2(temp)
    return (total1/float(total1+total2))*dy + (total2/float(total1+total2))*dn
class DecisionTree:
    ''' Implements the Decision Tree For Classification... '''
    def __init__(self, purityp, exthreshold,maxdepth=10):        
        self.purity=purityp
        self.exthreshold=exthreshold
        self.maxdepth=maxdepth
        self.tree = None
        
    def train(self, X, Y):
        ''' Train Decision Tree using the given 
            X [m x d] data matrix and Y labels matrix
            
            Input:
            ------
            X: [m x d] a data matrix of m d-dimensional examples.
            Y: [m x 1] a label vector.
            
            Returns:
            -----------
            Nothing
            '''
        nexamples,nfeatures=X.shape
        ## now go and train a model for each class...
        # YOUR CODE HERE
        self.tree = self.build_tree(X,Y,self.maxdepth)
        


        
        
    def build_tree(self, X, Y, depth):
        """ 
            Function is used to recursively build the decision Tree 
          
            Input
            -----
            X: [m x d] a data matrix of m d-dimensional examples.
            Y: [m x 1] a label vector.
            
            Returns
            -------
            root node of the built tree...
        """
        nexamples, nfeatures=X.shape
      
        klasses=np.unique(Y);
        # YOUR CODE HERE
        size = X.shape[0]
        unique,counts = np.unique(Y,return_counts=True)
        purity = max(counts)/float(sum(counts))
        if (size < self.exthreshold or purity >= self.purity and depth >= 0):
            c = unique[np.argmax(counts)]
            leafNode = Node(purity,c)
            return leafNode
        V = []
        S = []
        xlid = []
        xrid = []
        
        for i in range(0,X.shape[1]):
            v,s,xlidx,xridx = self.evaluate_numerical_attribute(X[:,i],Y)
            
            V.append(v)
            S.append(s)
            xlid.append(xlidx)
            xrid.append(xridx)
        S = np.array(S)
        ind = np.argmin(S)
        node = Node(purity)
        node.score = S[ind]
        node.fidx = ind
        node.split = V[ind]
        Dy = X[xlid[ind]]
        Dn = X[xrid[ind]]
        Dyl = Y[xlid[ind]]  # Dyl Labels
        Dnl = Y[xrid[ind]]  # Dnl labels
#         print Dy,Dyl
#         print Dn,Dnl
        node.set_childs(self.build_tree(Dy,Dyl,depth-1),self.build_tree(Dn,Dnl,depth-1))
#         node.lchild = self.build_tree(Dy,Dyl,depth-1)
#         node.rchild = self.build_tree(Dn,Dnl,depth-1)
#         self.tree = node
        return node
            
        
    def test(self, X):
        
        ''' Test the trained classifiers on the given set of examples 
        
                   
            Input:
            ------
            X: [m x d] a data matrix of m d-dimensional test examples.
           
            Returns:
            -----------
                pclass: the predicted class for each example, i.e. to which it belongs
        '''
        
        nexamples, nfeatures=X.shape
        pclasses=self.predict(X)
        
        # your code go here...
        pclass = []
#         for i in X:
            
            
        
    
    def evaluate_numerical_attribute(self,feat, Y):
        '''
            Evaluates the numerical attribute for all possible split points for
            possible feature selection
            
            Input:
            ---------
            feat: a contiuous feature
            Y: labels
            
            Returns:
            ----------
            v: splitting threshold
            score: splitting score
            Xlidx: Index of examples belonging to left child node
            Xridx: Index of examples belonging to right child node
            
        '''
        
        # A big source of Bugs will be sorting the same array and expecting it to behave original,
        # use separate variables to store the sorted array and its corresponding classes labels...
        
        classes=np.unique(Y)
        nclasses=len(classes)
        sidx=np.argsort(feat)
        f=feat[sidx] # sorted features
        sY=Y[sidx] # sorted feat
        ures class labels...
        
        # YOUR CODE HERE
#         n = []
        n = np.zeros((classes.shape[0]))
        N = []
#         midPoints = (f[1:] + f[:-1]) / 2
        midPoints = []
        for j in range(0,sY.shape[0]-1):
            n[classes == sY[j]] += 1
#             print n
            if (f[j+1] != f[j]):
                m = (f[j+1] + f[j]) / 2    # Mid Point between to adjacent points
                midPoints.append(m)  
                N.append(np.array(n))
        n[classes == sY[sY.shape[0]-1]] += 1
        N = np.array(N)
        e = []
#         print N
        for i in N:
            e.append(calculateSplitScore(i,n))
        e = np.array(e)
        ind = np.argmin(e)    # minimum split score index
        v = midPoints[ind]    # Best split point  
        score = e[ind]        # Best Split Score
        xlidx = np.argwhere(f<v)
        xridx = np.argwhere(f>v)
        return v,score,xlidx.reshape((xlidx.shape[0],)),xridx.reshape((xridx.shape[0],))
        
        
            
    
    def predict(self, X):
        
        """
        Test the trained classifiers on the given example X
        
                   
            Input:
            ------
            X: [1 x d] a d-dimensional test example.
           
            Returns:
            -----------
                pclass: the predicted class for the given example, i.e. to which it belongs
        """
        return self._predict(self.tree,X)
    
    def _predict(self,node, X):
        # YOUR CODE HERE
        pclasses = []
        for i in X:
            temp = node
            while not(temp.isleaf()):
                if (i[temp.fidx] <= temp.split):
                    temp = temp.lchild
                else:
                    temp = temp.rchild
            pclasses.append(temp.klasslabel)
        return pclasses
            
        

    def __str__(self):
        
        return self.__print(self.tree)  
    
        
     
    def find_depth(self):
        
        return self._find_depth(self.tree)
    
    
    def _find_depth(self,node):
        if not node:
            return
        if node.isleaf():
            return 1
        else:
            return max(self._find_depth(node.lchild),self._find_depth(node.rchild))+1
        
    def __print(self,node,depth=0):
        
        ret = ""

        # Print right branch
        if node.rchild:
            ret += self.__print(node.rchild,depth+1)

        # Print own value
        
        ret += "\n" + ("    "*depth) + node.get_str()

        # Print left branch
        if node.lchild:
            ret += self.__print(node.lchild,depth+1)
        
        return ret

# %%
# feat=[0,1]
# dt=DecisionTree(0.95,5,2)
# dt.evaluate_numerical_attribute(X[:,0],Y)
# # print X[:,0]
# # print ((X[:,0][1:] + X[:,0][:-1]) / 2)
print np.logical_not(X[:,1] < 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-95b8b62515ac> in <module>()
#       4 # # print X[:,0]
#       5 # # print ((X[:,0][1:] + X[:,0][:-1]) / 2)
# ----> 6 print np.logical_not(X[:,1] < 3)
#
# NameError: name 'X' is not defined

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..

# %%
#load the data set
data=pd.read_csv('./iris.data')
data.columns=['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
print data.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   149.000000  149.000000   149.000000  149.000000
# mean      5.848322    3.051007     3.774497    1.205369
# std       0.828594    0.433499     1.759651    0.761292
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.400000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
# Get your data in matrix
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())
print " Data Set Dimensions=", X.shape, " True Class labels dimensions", Y.shape
# Out:
#  Data Set Dimensions= (149, 4)  True Class labels dimensions (149,)

# %%
print Y
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %%
Y[Y=='Iris-virginica']='Iris-versicolor'
print Y, len(Y), np.unique(Y)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'] 149 ['Iris-setosa' 'Iris-versicolor']

# %% [markdown]
# ### Debugging Tip
# You can import pdb and call its function set_trace (i.e pdb.set_trace()) any where in your code to stop the execution of your code and inspect it line by line by using pdf. Otherwise, you can use Pycharm GUI debugger.

# %%
# import pdb 
# pdb.set_trace()

# %%
np.sum((X[:,0]<=5.45) & (Y=='Iris-versicolor'))
# Out:
# 7

# %%
print ['{:0.5}'.format(p) for p in X[:,0]]
# Out:
# ['4.9', '4.7', '4.6', '5.0', '5.4', '4.6', '5.0', '4.4', '4.9', '5.4', '4.8', '4.8', '4.3', '5.8', '5.7', '5.4', '5.1', '5.7', '5.1', '5.4', '5.1', '4.6', '5.1', '4.8', '5.0', '5.0', '5.2', '5.2', '4.7', '4.8', '5.4', '5.2', '5.5', '4.9', '5.0', '5.5', '4.9', '4.4', '5.1', '5.0', '4.5', '4.4', '5.0', '5.1', '4.8', '5.1', '4.6', '5.3', '5.0', '7.0', '6.4', '6.9', '5.5', '6.5', '5.7', '6.3', '4.9', '6.6', '5.2', '5.0', '5.9', '6.0', '6.1', '5.6', '6.7', '5.6', '5.8', '6.2', '5.6', '5.9', '6.1', '6.3', '6.1', '6.4', '6.6', '6.8', '6.7', '6.0', '5.7', '5.5', '5.5', '5.8', '6.0', '5.4', '6.0', '6.7', '6.3', '5.6', '5.5', '5.5', '6.1', '5.8', '5.0', '5.6', '5.7', '5.7', '6.2', '5.1', '5.7', '6.3', '5.8', '7.1', '6.3', '6.5', '7.6', '4.9', '7.3', '6.7', '7.2', '6.5', '6.4', '6.8', '5.7', '5.8', '6.4', '6.5', '7.7', '7.7', '6.0', '6.9', '5.6', '7.7', '6.3', '6.7', '7.2', '6.2', '6.1', '6.4', '7.2', '7.4', '7.9', '6.4', '6.3', '6.1', '7.7', '6.3', '6.4', '6.0', '6.9', '6.7', '6.9', '5.8', '6.8', '6.7', '6.7', '6.3', '6.5', '6.2', '5.9']

# %%
print len(Y)
feat=[0,1]
dt=DecisionTree(0.95,5,2)
feat=[0,1]
dt.classes=np.unique(Y)
dt.nclasses=len(np.unique(Y))
split,mingain,Xlidx,Xridx=dt.evaluate_numerical_attribute(X[:,0],Y)
print split,mingain


# You should get following result:, see the example on book page 490-491, Data Mining and Analysis...
# Split=5.45, H(DY)=0.577004250316,P(DY)=0.342281879195,H(DN)=0.290715865467,P(DN)=0.657718120805,gain=0.388707191825
# Out:
# 149
# 5.45 0.388707191825

# %%
dt.classes=np.unique(Y)
dt.nclasses=len(np.unique(Y))
split,mingain,Xlidx,Xridx=dt.evaluate_numerical_attribute(X[:,0],Y)

# %%
from nose.tools import assert_almost_equal, assert_equal

assert_equal(split, 5.45)
assert_almost_equal(mingain, 0.38, places=1)

# %%
Y[Y=='Iris-virginica']='Iris-versicolor'
print len(Y)
feat=[2,3]
dt=DecisionTree(0.95,5)
n = dt.build_tree(X[:,feat],Y,10)
dt.train(X[:,feat],Y)
# g,s,xl,xr=dt.evaluate_numerical_attribute(X[:,2],Y)
#print g, s, xl, xr
# Out:
# 149

# %%
print dt
# Out:
#     C(class=Iris-versicolor,Purity=1.0)
# I(Fidx=0,Score=0.0,Split=2.45)
#     C(class=Iris-setosa,Purity=1.0)

# %%
print dt.find_depth()
# Out:
# 2

# %%
# %pdb
print " Plotting the Decision Surface of Training Set... "
t.plot_decision_regions(X[:,feat],Y,clf=dt, res=0.1, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Training Set...

# %%
# Split your data into training and test-set... 
# see the documentation of split_data in tools for further information...
Xtrain,Ytrain,Xtest,Ytest=t.split_data(X,Y)

print " Training Data Set Dimensions=", Xtrain.shape, "Training True Class labels dimensions", Ytrain.shape   
print " Test Data Set Dimensions=", Xtest.shape, "Test True Class labels dimensions", Ytrain.shape
# Out:
#  Training Data Set Dimensions= (51, 4) Training True Class labels dimensions (51,)
#  Test Data Set Dimensions= (22, 4) Test True Class labels dimensions (51,)

# %%
# Lets train a Decision Tree Classifier on Petal Length and Width
feat=[0,1]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)

# %%
#Lets test it on the set of unseen examples...
pclasses=dt.predict(Xtest[:,feat])

# %%
print pclasses
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor']

# %% [markdown]
# Lets see how good we are doing...
# ==================

# %%
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 41
# Accuracy =  0.911111111111

# %%
#Lets plot the decision surface
print " Plotting the Decision Surface of Training Set... "
t.plot_decision_regions(Xtrain[:,feat],Ytrain,clf=dt, res=0.02, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Training Set...

# %%
print " Plotting the Decision Surface of Test Set... "
t.plot_decision_regions(Xtest[:,feat],Ytest,clf=dt, res=0.02, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Test Set...

# %%
from nose.tools import assert_greater_equal
feat=[0,1]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
acc = np.sum(pclasses==Ytest)/float(Ytest.shape[0])
assert_greater_equal(acc, 0.90)

# %% [markdown]
# # Lets Train on all four features....

# %%
#Lets Train on all four features....

# Lets train a Decision Tree Classifier on Petal Length and Width
feat=[0, 1, 2, 3]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 45
# Accuracy =  1.0

# %% [markdown]
# # Lets Train on all four features and for all three classes....

# %%
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())
print " Data Set Dimensions=", X.shape, " True Class labels dimensions", Y.shape
# Out:
#  Data Set Dimensions= (149, 4)  True Class labels dimensions (149,)

# %%
# Split your data into training and test-set... 
# see the documentation of split_data in tools for further information...
Xtrain,Ytrain,Xtest,Ytest=t.split_data(X,Y)

print " Training Data Set Dimensions=", Xtrain.shape, "Training True Class labels dimensions", Ytrain.shape   
print " Test Data Set Dimensions=", Xtest.shape, "Test True Class labels dimensions", Ytrain.shape
# Out:
#  Training Data Set Dimensions= (104, 4) Training True Class labels dimensions (104,)
#  Test Data Set Dimensions= (45, 4) Test True Class labels dimensions (104,)

# %%
feat=[0, 1, 2, 3]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 43
# Accuracy =  0.955555555556

# %%
from nose.tools import assert_greater_equal

feat=[0, 1, 2, 3]
dt=DecisionTree(0.95,5)
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
acc = np.sum(pclasses==Ytest)/float(Ytest.shape[0])
assert_greater_equal(acc, 0.90)

# %% [markdown]
# What can you conclude ?
# ====================
# Please write your observation....

# %% [markdown]
# # Cross-Validation
#
# Until now we have been splitting the dataset into a training and test set rather randomly and were reporting a rather artifical performance. Now we are going to test our system exhaustively by making use of k-fold [cross validation](http://en.wikipedia.org/wiki/Cross-validation_%28statistics%29).
#
# Now go and tune your hyper-parameters (purity, exthreshold) to opitmize the performance.

# %%
# Now lets cross validate for best paramters, and test the result...
# We will be training four different models on four different partitions of data set and 
# then will be reporting the mean accuracy of the four classifiers.

# import time
nfolds=4 # lets use four folds..
folds=t.generate_folds(X,Y,nfolds)
features=[0,1, 2, 3] # features to use for our system
#now lets train and test on these folds...

#Lets perform the grid search...
purity=np.linspace(0.85,0.97,13) # You can also search over depth as well....
nexamp=np.linspace(5,25,21)  

params=np.zeros((len(purity),len(nexamp)))
foldacc = []






for i in range(len(purity)):
    for j in range(len(nexamp)):
        dt = DecisionTree(purity[i],nexamp[j])
        totacc = []
        for f in range(nfolds):

            traindata=folds[f][0]
            trainlabels=folds[f][1]

            #Lets first train the classifier
    #         nb.train(traindata,trainlabels)
            dt.train(traindata[:,features],trainlabels)
#                 knn.train(traindata[:,features],trainlabels)

            testdata=folds[f][2]
            testlabels=folds[f][3]

            #Lets test the classifier
    #         pclasses= nb.test(testdata)
            pclasses=dt.predict(testdata[:,features])

            #print pclasses
            acc=np.sum(pclasses==testlabels)/float(testlabels.shape[0])
            print "[Info] Fold {} Accuracy = {}".format(f+1, acc)    
            totacc.append(acc)
        #foldacc.append(np.mean(np.array(totacc)))
        params[i][j] = np.mean(totacc)
        print  "purity = ",i,"Nexample-threshold = ",j,"Mean Accuracy = ",params[i][j]
# Out:
#  Generating CV data for 3 classes
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  0 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  1 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  2 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  3 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  4 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  5 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  6 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  7 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  8 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  9 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  10 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  11 Nexample-threshold =  20 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  0 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  1 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  2 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  3 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  4 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  5 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  6 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  7 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  8 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  9 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  10 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  11 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  12 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  13 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  14 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  15 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  16 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  17 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  18 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  19 Mean Accuracy =  0.944444444444
# [Info] Fold 1 Accuracy = 0.972222222222
# [Info] Fold 2 Accuracy = 0.916666666667
# [Info] Fold 3 Accuracy = 0.944444444444
# [Info] Fold 4 Accuracy = 0.944444444444
# purity =  12 Nexample-threshold =  20 Mean Accuracy =  0.944444444444

# %%
np.save('dt-cv',params)

# %%
print params
# Out:
# [[ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]
#  [ 0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444  0.94444444  0.94444444  0.94444444
#    0.94444444  0.94444444  0.94444444]]

# %%
print params.shape
# Out:
# (13, 21)

# %%
plt.imshow(params) # displayc the accuracy as 2D image...

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
tX, tY = np.meshgrid(purity, nexamp)
ax.plot_surface(tX,tY,params.T)
ax.set_xlabel('Purity')
ax.set_ylabel('Nexamples')
ax.set_zlabel('Mean Accuracy across {}-Folds'.format(nfolds))
# ax.scatter3D(data['SepalLength'],data['PetalLength'],data['PetalWidth'])
#(params,ax,'Purity','Example-Threshold','Mean-Accuracy')
# Out:
# Text(0.5,0,u'Mean Accuracy across 4-Folds')

# %%
print params.shape, tX.shape, tY.shape
# Out:
# (13, 21) (21, 13) (21, 13)

# %%
#print the row and column  index of m
#single line code
ridx,cidx= np.unravel_index(np.argmax(params), params.shape)

# simple step-wise code

cidx=np.argmax(params.max(axis=0))
ridx=np.argmax(params[:,cidx])
print ridx, cidx
# Out:
# 0 0

# %%
print 'CV Best Parameters are, purity={}, nexamp={}, mean accuracy={}'.format(purity[ridx],nexamp[cidx],params[ridx,cidx])
# Out:
# CV Best Parameters are, purity=0.85, nexamp=5.0, mean accuracy=0.930555555556

# %%
print purity[ridx],nexamp[cidx]
dt=DecisionTree(purity[ridx],nexamp[cidx])
dt.train(Xtrain[:,feat],Ytrain)
pclasses=dt.predict(Xtest[:,feat])
#Lets see how good we are doing, by finding the accuracy on the test set..
print np.sum(pclasses==Ytest)
print "Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0])
# Out:
# 0.85 5.0
# 43
# Accuracy =  0.955555555556

# %%
print dt.find_depth()
# Out:
# 3

# %%
print dt
# Out:
#         C(class=Iris-virginica,Purity=1.0)
#     I(Fidx=3,Score=0.265796870608,Split=1.75)
#         C(class=Iris-versicolor,Purity=0.897435897436)
# I(Fidx=2,Score=0.673076923077,Split=2.45)
#     C(class=Iris-setosa,Purity=1.0)
